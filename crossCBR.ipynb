# %%
# !git clone https://github.com/hoangpanda/CrossCBR.git
# Out:
# Cloning into 'CrossCBR'...
# remote: Enumerating objects: 705, done.
# remote: Counting objects: 100% (259/259), done.
# remote: Compressing objects: 100% (126/126), done.
# remote: Total 705 (delta 163), reused 217 (delta 126), pack-reused 446
# Receiving objects: 100% (705/705), 88.95 MiB | 24.66 MiB/s, done.
# Resolving deltas: 100% (318/318), done.

# %%
# %cd CrossCBR
# Out:
# /content/CrossCBR

# %%
# !ls
# Out:
# config.yaml  datasets  models  README.md  train.py  utility.py

# %%
# !pip install torch_geometric -q
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 9.7 MB/s eta 0:00:00
# ...

# %%
# !python train.py -g 0 -m CrossCBR -d Yo
# Out:
# Streaming output truncated to the last 5000 lines.
# A_feature: Parameter containing:
# tensor([[-0.0453,  0.0268, -0.0016,  ...,  0.0359,  0.0106,  0.0897],
#         [ 0.0516, -0.1111,  0.0800,  ..., -0.0374,  0.0402,  0.0503],
#         [ 0.0112,  0.0067,  0.0206,  ..., -0.0050,  0.0500, -0.0403],
#         ...,
#         [-0.0730, -0.0293,  0.0235,  ...,  0.0589, -0.0023, -0.0941],
#         [ 0.0547,  0.0553,  0.0563,  ...,  0.0611, -0.0506,  0.0728],
#         [ 0.1004,  0.1130,  0.1033,  ...,  0.0612, -0.0501, -0.0106]],
#        device='cuda:0', requires_grad=True)
# B_feature shape: torch.Size([4487, 64])
# B_feature: Parameter containing:
# tensor([[-0.0107,  0.0080,  0.0071,  ..., -0.0100,  0.0070, -0.0253],
#         [-0.0156, -0.0487, -0.0188,  ...,  0.0049,  0.0076,  0.0196],
#         [-0.0076,  0.0409,  0.0371,  ...,  0.0191, -0.0153,  0.0315],
#         ...,
#         [-0.0247, -0.0161, -0.0075,  ..., -0.0100, -0.0294,  0.0028],
# ...
